# %%
import osmnx


# networkx graph of the named place
graph = osmnx.graph_from_xml("map")

# Plot the graphs
osmnx.plot_graph(graph,figsize=(10,20))
# Out:
# (<Figure size 1000x2000 with 1 Axes>, <Axes: >)
